# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings 
import math
import datetime

# %%
df=pd.read_csv("customer_shopping_behavior.csv")

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %% [markdown]
# #### Checking Shape (rows-columns)

# %%
df.shape
# Out:
# (3900, 18)

# %% [markdown]
# #### Checking & Handling Null-Values

# %%
df.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %% [markdown]
# #### Checking Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Changing Columns names

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %%
df.columns=df.columns.str.lower().str.replace(" ","_")
df=df.rename(columns={'purchase_amount_(usd)':'purchase_amount'})

# %%
df.head()
# Out:
#    customer_id  age gender item_purchased  category  purchase_amount  \
# 0            1   55   Male         Blouse  Clothing               53
# 1            2   19   Male        Sweater  Clothing               64
# 2            3   50   Male          Jeans  Clothing               73
# 3            4   21   Male        Sandals  Footwear               90
# 4            5   45   Male         Blouse  Clothing               49
#
#         location size      color  season  review_rating subscription_status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    shipping_type discount_applied promo_code_used  previous_purchases  \
# ...

# %% [markdown]
# ### Create a new column

# %%
label=['Young Adult','Adult','Middle-aged','Senior']
df['age_group']=pd.qcut(df['age'],q=4,labels=label)

# %%
df.groupby('age_group')['age'].count()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_22180\927777213.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('age_group')['age'].count()
# age_group
# Young Adult    1028
# Adult           942
# Middle-aged     986
# Senior          944
# Name: age, dtype: int64

# %% [markdown]
# #### Create column purchase_freq_days

# %%
df['frequency_of_purchases'].unique()
# Out:
# array(['Fortnightly', 'Weekly', 'Annually', 'Quarterly', 'Bi-Weekly',
#        'Monthly', 'Every 3 Months'], dtype=object)

# %%
freq={'Fortnightly':14,
      'Weekly':7,
      'Annually':365,
      'Quarterly':90,
      'Bi-Weekly':14,
      'Monthly':30,
      'Every 3 Months':90
}

# %%
df['purchase_freq_day']=df['frequency_of_purchases'].map(freq)

# %%
df[['purchase_freq_day','frequency_of_purchases']].head()
# Out:
#    purchase_freq_day frequency_of_purchases
# 0                 14            Fortnightly
# 1                 14            Fortnightly
# 2                  7                 Weekly
# 3                  7                 Weekly
# 4                365               Annually

# %%
df[['discount_applied','promo_code_used']].head(10)
# Out:
#   discount_applied promo_code_used
# 0              Yes             Yes
# 1              Yes             Yes
# 2              Yes             Yes
# 3              Yes             Yes
# 4              Yes             Yes
# 5              Yes             Yes
# 6              Yes             Yes
# 7              Yes             Yes
# 8              Yes             Yes
# 9              Yes             Yes

# %% [markdown]
# #### Checking if both the columns carry equal value or data

# %% [markdown]
# ##### all is used to check 2 columns values if equal True alse False

# %%
(df['discount_applied']==df['promo_code_used']).all()
# Out:
# np.True_

# %%
df=df.drop('promo_code_used',axis=1)

# %%
import mysql.connector
from mysql.connector import Error

# %%
config={
    'user': "root",
    'password':'Mayank@400250',
    'host':'localhost',
    'database':'ex1',
    'port':3306
}
try:
    conn=mysql.connector.connect(**config)
    if conn.is_connected():
        print("Connection Established")
        cursor=conn.cursor()
except mysql.connector.Error as e:
    print("Error connecting to mysql")
# Out:
# Connection Established

# %%
from sqlalchemy import create_engine
import urllib.parse
import pymysql
username="root"
password="Mayank@400250"
host="localhost"
port=3306
database="ex1"
safe_password = urllib.parse.quote_plus(password)
db_connection_str = f'mysql+pymysql://{username}:{safe_password}@{host}:{port}/{database}'
engine = create_engine(db_connection_str)

# %%
df.to_sql(name="customer_behaviour",con=engine,if_exists="replace",index=False)
# Out:
# 3900
